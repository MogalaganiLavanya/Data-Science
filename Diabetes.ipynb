# %% [markdown]
# <a href="https://colab.research.google.com/github/MogalaganiLavanya/Data-Science/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes (2).csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot = True,cmap='Greens')
# Out:
# <Axes: >

# %%
x=df.iloc[:,:-1]
y= df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB = GaussianNB()

# %%
NB.fit(x_train,y_train)
y_pred = NB.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score

# %%
nb_scores = cross_val_score(NB, x, y, cv=5)
print("Naive Bayes Cross-validation scores:", nb_scores)
print("Average Naive Bayes accuracy:", nb_scores.mean())
# Out:
# Naive Bayes Cross-validation scores: [0.75324675 0.72727273 0.74675325 0.78431373 0.74509804]
# Average Naive Bayes accuracy: 0.7513368983957219

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
acc = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)

# %%
f"the performance of Naive Bayes model is {acc},classification report is {cr} and confusion matrix is {cm}"
# Out:
# 'the performance of Naive Bayes model is 0.7922077922077922,classification report is               precision    recall  f1-score   support\n\n           0       0.84      0.87      0.85       107\n           1       0.67      0.62      0.64        47\n\n    accuracy                           0.79       154\n   macro avg       0.76      0.74      0.75       154\nweighted avg       0.79      0.79      0.79       154\n and confusion matrix is [[93 14]\n [18 29]]'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
acc = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)

# %%
rf_scores = cross_val_score(rf, x, y, cv=5)
print("Random Forest Cross-validation scores:", rf_scores)
print("Average Random Forest accuracy:", rf_scores.mean())
# Out:
# Random Forest Cross-validation scores: [0.74025974 0.73376623 0.75974026 0.81045752 0.74509804]
# Average Random Forest accuracy: 0.7578643578643579

# %%
f"the performance of random forest model is {acc},classification report is {cr} and confusion matrix is {cm}"
# Out:
# 'the performance of random forest model is 0.8116883116883117,classification report is               precision    recall  f1-score   support\n\n           0       0.86      0.87      0.87       107\n           1       0.70      0.68      0.69        47\n\n    accuracy                           0.81       154\n   macro avg       0.78      0.78      0.78       154\nweighted avg       0.81      0.81      0.81       154\n and confusion matrix is [[93 14]\n [15 32]]'

# %%
import pickle

# %%
with open('random_forest_model.pkl','wb') as f:
  pickle.dump(rf,f)
